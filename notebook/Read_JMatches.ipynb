# %%
import sys
from datetime import datetime
sys.path.append('../src/')
from read_jleague_matches import update_all_matches, read_matches_range

# %%
#CATEGORY = 3

#all_matches = read_all_matches(CATEGORY)
# all_matches.to_csv(f'match_result-J{CATEGORY}-{datetime.now().strftime("%Y%m%d")}.csv')

#all_matches

# %%
current_matches = update_all_matches(1)
need_update = {'19', '30'}
diff_matches = read_matches_range(1, need_update)
# Out:
# match file "../csv/match_result-J1-20210530.csv" reading.
# {'19', '30'} set()

# %%
current_matches
# Out:
#    match_date section_no match_index_in_section start_time stadium home_team  \
# 0  2021-02-26          1                      1      18:04     等々力      横浜FM
# 1  2021-02-27          1                      2      14:00     札幌ド      横浜FC
# 2  2021-02-27          1                      3      14:00      埼玉      FC東京
# 3  2021-02-27          1                      4      14:03     Ｅスタ        仙台
# 4  2021-02-27          1                      5      14:03    昭和電ド        徳島
# ..        ...        ...                    ...        ...     ...       ...
# 5  2021-12-04         38                      6         未定    アイスタ       Ｃ大阪
# 6  2021-12-04         38                      7         未定     豊田ス        浦和
# 7  2021-12-04         38                      8         未定    パナスタ        湘南
# 8  2021-12-04         38                      9         未定    鳴門大塚        広島
# 9  2021-12-04         38                     10         未定     駅スタ        神戸
#
#    home_goal away_goal away_team
# 0          0         2       川崎Ｆ
# 1          1         5        札幌
# 2          1         1        浦和
# 3          1         1        広島
# 4          1         1        大分
# ..       ...       ...       ...
# 5                             清水
# 6                            名古屋
# 7                            Ｇ大阪
# 8                             徳島
# 9                             鳥栖
#
# [380 rows x 9 columns]

# %%
diff_matches
# Out:
#   match_date section_no  match_index_in_section start_time stadium home_team  \
# 0 2021-04-14         19                       1      19:03     等々力        福岡
# 1 2021-04-14         19                       2      19:33     豊田ス        広島
# 2 2021-06-02         19                       3      19:00    レモンＳ       Ｇ大阪
# 3 2021-06-23         19                       4      19:00    ユアスタ        清水
# 4 2021-06-23         19                       5      19:00    三協Ｆ柏        浦和
# 5 2021-06-23         19                       6      19:00    ニッパツ        鳥栖
# 6 2021-06-23         19                       7      19:00    ノエスタ      横浜FC
# 7 2021-06-23         19                       8      19:00    鳴門大塚      FC東京
# 8 2021-06-23         19                       9      19:00    昭和電ド        鹿島
# 9        NaT         19                      10         未定      未定       Ｃ大阪
# 0 2021-09-24         30                       1         未定    アイスタ        神戸
# 1 2021-09-25         30                       2         未定     札幌ド        広島
# 2 2021-09-25         30                       3         未定    ユアスタ        徳島
# 3 2021-09-25         30                       4         未定     味スタ        浦和
# 4 2021-09-25         30                       5         未定     等々力        湘南
# 5 2021-09-25         30                       6         未定    ニッパツ      横浜FM
# 6 2021-09-25         30                       7         未定    パナスタ         柏
# 7 2021-09-25         30                       8         未定    ヨドコウ        鹿島
# 8 2021-09-25         30                       9         未定    ベススタ        鳥栖
# 9        NaT         30                      10         未定      未定        大分
#
#   home_goal away_goal away_team
# 0         1         3       川崎Ｆ
# 1         0         1       名古屋
# 2                            湘南
# 3                            仙台
# 4                             柏
# 5                          横浜FM
# 6                            神戸
# 7                            徳島
# 8                            大分
# 9                            札幌
# 0                            清水
# 1                            札幌
# 2                            仙台
# 3                          FC東京
# 4                           川崎Ｆ
# 5                          横浜FC
# 6                           Ｇ大阪
# 7                           Ｃ大阪
# 8                            福岡
# 9                           名古屋

# %%
current_matches[~current_matches['section_no'].isin(need_update)]
# Out:
#    match_date section_no match_index_in_section start_time stadium home_team  \
# 0  2021-02-26          1                      1      18:04     等々力      横浜FM
# 1  2021-02-27          1                      2      14:00     札幌ド      横浜FC
# 2  2021-02-27          1                      3      14:00      埼玉      FC東京
# 3  2021-02-27          1                      4      14:03     Ｅスタ        仙台
# 4  2021-02-27          1                      5      14:03    昭和電ド        徳島
# ..        ...        ...                    ...        ...     ...       ...
# 5  2021-12-04         38                      6         未定    アイスタ       Ｃ大阪
# 6  2021-12-04         38                      7         未定     豊田ス        浦和
# 7  2021-12-04         38                      8         未定    パナスタ        湘南
# 8  2021-12-04         38                      9         未定    鳴門大塚        広島
# 9  2021-12-04         38                     10         未定     駅スタ        神戸
#
#    home_goal away_goal away_team
# 0          0         2       川崎Ｆ
# 1          1         5        札幌
# 2          1         1        浦和
# 3          1         1        広島
# 4          1         1        大分
# ..       ...       ...       ...
# 5                             清水
# 6                            名古屋
# 7                            Ｇ大阪
# 8                             徳島
# 9                             鳥栖
#
# [360 rows x 9 columns]

# %%
import pandas as pd
# Out:
#      index match_date section_no match_index_in_section start_time stadium  \
# 0        0 2021-02-26          1                      1      18:04     等々力
# 1        1 2021-02-27          1                      2      14:00     札幌ド
# 2        2 2021-02-27          1                      3      14:00      埼玉
# 3        3 2021-02-27          1                      4      14:03     Ｅスタ
# 4        4 2021-02-27          1                      5      14:03    昭和電ド
# ..     ...        ...        ...                    ...        ...     ...
# 375      5 2021-09-25         30                      6         未定    ニッパツ
# 376      6 2021-09-25         30                      7         未定    パナスタ
# 377      7 2021-09-25         30                      8         未定    ヨドコウ
# 378      8 2021-09-25         30                      9         未定    ベススタ
# 379      9        NaT         30                     10         未定      未定
#
#     home_team home_goal away_goal away_team
# 0        横浜FM         0         2       川崎Ｆ
# 1        横浜FC         1         5        札幌
# 2        FC東京         1         1        浦和
# 3          仙台         1         1        広島
# 4          徳島         1         1        大分
# ..        ...       ...       ...       ...
# 375      横浜FM                          横浜FC
# 376         柏                           Ｇ大阪
# 377        鹿島                           Ｃ大阪
# 378        鳥栖                            福岡
# 379        大分                           名古屋
#
# [380 rows x 10 columns]
