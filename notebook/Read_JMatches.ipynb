# %%
import sys
from datetime import datetime
sys.path.append('../src/')
from read_jleague_matches import read_all_matches, update_all_matches, read_matches_range

# %%
CATEGORY = 3

all_matches = read_all_matches(CATEGORY)
# all_matches.to_csv(f'match_result-J{CATEGORY}-{datetime.now().strftime("%Y%m%d")}.csv')

all_matches
# Out:
#    match_date section_no  match_index_in_section start_time stadium home_team  \
# 0  2021-03-14          1                       1      13:03    とうスタ        藤枝
# 1  2021-03-14          1                       2      13:03    ニッパツ        富山
# 2  2021-03-14          1                       3      13:03     夢スタ        熊本
# 3  2021-03-14          1                       4      13:03    ユニスタ        岩手
# 4  2021-03-14          1                       5      14:03     長良川        八戸
# ..        ...        ...                     ...        ...     ...       ...
# 2  2021-11-28         29                       3         未定     長良川        藤枝
# 3  2021-11-28         29                       4         未定     夢スタ        八戸
# 4  2021-11-28         29                       5         未定    白波スタ        長野
# 5  2021-11-28         29                       6         未定    ユニスタ        熊本
# 6         NaT         29                       7         未定      未定        鳥取
#
#    home_goal away_goal away_team
# 0          0         0        福島
# 1          1         0      YS横浜
# 2          1         0        今治
# 3          1         0        宮崎
# 4          0         0        岐阜
# ..       ...       ...       ...
# 2                             岐阜
# 3                             今治
# 4                            鹿児島
# 5                             宮崎
# 6                             讃岐
#
# [203 rows x 9 columns]

# %%
sec30 = read_matches_range(3, [30])
sec30
# Out:
#   match_date section_no  match_index_in_section start_time stadium home_team  \
# 0 2021-12-05         30                       1         未定    とうスタ        讃岐
# 1 2021-12-05         30                       2         未定     長野Ｕ        今治
# 2 2021-12-05         30                       3         未定      富山       鹿児島
# 3 2021-12-05         30                       4         未定     藤枝サ      YS横浜
# 4 2021-12-05         30                       5         未定      愛鷹        岩手
# 5 2021-12-05         30                       6         未定    Ａｘｉｓ        八戸
# 6 2021-12-05         30                       7         未定    えがおＳ        岐阜
#
#   home_goal away_goal away_team
# 0                            福島
# 1                            長野
# 2                            富山
# 3                            藤枝
# 4                            沼津
# 5                            鳥取
# 6                            熊本

# %%
all_matches[all_matches['section_no'] == 30]
# Out:
# Empty DataFrame
# Columns: [match_date, section_no, match_index_in_section, start_time, stadium, home_team, home_goal, away_goal, away_team]
# Index: []

# %%
current_matches = update_all_matches(1)
#diff_matches = read_matches_range(1, need_update)
# Out:
# match file "../csv/match_result-J1-20210528.csv" reading.

# %%
current_matches
# Out:
#      index match_date section_no match_index_in_section start_time stadium  \
# 0        0 2021-02-26          1                      1      18:04     等々力
# 1        1 2021-02-27          1                      2      14:00     札幌ド
# 2        2 2021-02-27          1                      3      14:00      埼玉
# 3        3 2021-02-27          1                      4      14:03     Ｅスタ
# 4        4 2021-02-27          1                      5      14:03    昭和電ド
# ..     ...        ...        ...                    ...        ...     ...
# 375      5 2021-05-30         17                      6      15:04    鳴門大塚
# 376      6 2021-05-30         17                      7      15:03    昭和電ド
# 377      7 2021-05-30         17                      8      17:03    パナスタ
# 378      8 2021-05-30         17                      9      18:04      埼玉
# 379      9 2021-05-30         17                     10      19:01     等々力
#
#     home_team home_goal away_goal away_team
# 0        横浜FM         0         2       川崎Ｆ
# 1        横浜FC         1         5        札幌
# 2        FC東京         1         1        浦和
# 3          仙台         1         1        広島
# 4          徳島         1         1        大分
# ..        ...       ...       ...       ...
# 375        湘南         1         1        徳島
# 376        福岡         1         2        大分
# 377      横浜FC         0         2       Ｇ大阪
# 378       名古屋         0         0        浦和
# 379        鹿島         1         2       川崎Ｆ
#
# [380 rows x 10 columns]
