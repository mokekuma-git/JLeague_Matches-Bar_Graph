# %%
import sys
from datetime import datetime
sys.path.append('../src/')
from read_jleague_matches import read_all_matches, update_all_matches, read_matches_range

# %%
CATEGORY = 3

all_matches = read_all_matches(CATEGORY)
# all_matches.to_csv(f'match_result-J{CATEGORY}-{datetime.now().strftime("%Y%m%d")}.csv')

all_matches
# Out:
# access https://www.jleague.jp/standings/j3/...
# access https://www.jleague.jp/match/section/j3/1/...
# access https://www.jleague.jp/match/section/j3/2/...
# access https://www.jleague.jp/match/section/j3/3/...
# access https://www.jleague.jp/match/section/j3/4/...
# access https://www.jleague.jp/match/section/j3/5/...
# access https://www.jleague.jp/match/section/j3/6/...
# access https://www.jleague.jp/match/section/j3/7/...
# access https://www.jleague.jp/match/section/j3/8/...
# access https://www.jleague.jp/match/section/j3/9/...
# access https://www.jleague.jp/match/section/j3/10/...
# access https://www.jleague.jp/match/section/j3/11/...
# access https://www.jleague.jp/match/section/j3/12/...
# access https://www.jleague.jp/match/section/j3/13/...
# access https://www.jleague.jp/match/section/j3/14/...
# access https://www.jleague.jp/match/section/j3/15/...
# access https://www.jleague.jp/match/section/j3/16/...
# access https://www.jleague.jp/match/section/j3/17/...
# access https://www.jleague.jp/match/section/j3/18/...
# access https://www.jleague.jp/match/section/j3/19/...
# access https://www.jleague.jp/match/section/j3/20/...
# access https://www.jleague.jp/match/section/j3/21/...
# access https://www.jleague.jp/match/section/j3/22/...
# access https://www.jleague.jp/match/section/j3/23/...
# access https://www.jleague.jp/match/section/j3/24/...
# access https://www.jleague.jp/match/section/j3/25/...
# access https://www.jleague.jp/match/section/j3/26/...
# access https://www.jleague.jp/match/section/j3/27/...
# access https://www.jleague.jp/match/section/j3/28/...
# access https://www.jleague.jp/match/section/j3/29/...
# access https://www.jleague.jp/match/section/j3/30/...
#    match_date section_no  match_index_in_section start_time stadium home_team  \
# 0  2021-03-14          1                       1      13:03    とうスタ        藤枝
# 1  2021-03-14          1                       2      13:03    ニッパツ        富山
# 2  2021-03-14          1                       3      13:03     夢スタ        熊本
# 3  2021-03-14          1                       4      13:03    ユニスタ        岩手
# 4  2021-03-14          1                       5      14:03     長良川        八戸
# ..        ...        ...                     ...        ...     ...       ...
# 2  2021-12-05         30                       3         未定      富山       鹿児島
# 3  2021-12-05         30                       4         未定     藤枝サ      YS横浜
# 4  2021-12-05         30                       5         未定      愛鷹        岩手
# 5  2021-12-05         30                       6         未定    Ａｘｉｓ        八戸
# 6  2021-12-05         30                       7         未定    えがおＳ        岐阜
#
#    home_goal away_goal away_team
# 0          0         0        福島
# 1          1         0      YS横浜
# 2          1         0        今治
# 3          1         0        宮崎
# 4          0         0        岐阜
# ..       ...       ...       ...
# 2                             富山
# 3                             藤枝
# 4                             沼津
# 5                             鳥取
# 6                             熊本
#
# [210 rows x 9 columns]

# %%
sec30 = read_matches_range(3, [30])
sec30
# Out:
# access https://www.jleague.jp/match/section/j3/30/...
#   match_date section_no  match_index_in_section start_time stadium home_team  \
# 0 2021-12-05         30                       1         未定    とうスタ        讃岐
# 1 2021-12-05         30                       2         未定     長野Ｕ        今治
# 2 2021-12-05         30                       3         未定      富山       鹿児島
# 3 2021-12-05         30                       4         未定     藤枝サ      YS横浜
# 4 2021-12-05         30                       5         未定      愛鷹        岩手
# 5 2021-12-05         30                       6         未定    Ａｘｉｓ        八戸
# 6 2021-12-05         30                       7         未定    えがおＳ        岐阜
#
#   home_goal away_goal away_team
# 0                            福島
# 1                            長野
# 2                            富山
# 3                            藤枝
# 4                            沼津
# 5                            鳥取
# 6                            熊本

# %%
all_matches[all_matches['section_no'] == 30]
# Out:
# Empty DataFrame
# Columns: [match_date, section_no, match_index_in_section, start_time, stadium, home_team, home_goal, away_goal, away_team]
# Index: []

# %%
current_matches = update_all_matches(1)
#diff_matches = read_matches_range(1, need_update)
# Out:
# match file "../csv/match_result-J1-20210605.csv" reading.

# %%
current_matches
# Out:
#     match_date section_no match_index_in_section start_time stadium home_team  \
# 0   2021-02-26          1                      1      18:04     等々力      横浜FM
# 1   2021-02-28          1                     10      13:05    ベススタ       名古屋
# 2   2021-02-27          1                      2      14:00     札幌ド      横浜FC
# 3   2021-02-27          1                      3      14:00      埼玉      FC東京
# 4   2021-02-27          1                      4      14:03     Ｅスタ        仙台
# ..         ...        ...                    ...        ...     ...       ...
# 375 2021-04-11          9                      5      14:03     味スタ       川崎Ｆ
# 376 2021-04-11          9                      6      15:03     駅スタ      横浜FC
# 377 2021-04-11          9                      7      15:03    昭和電ド       名古屋
# 378 2021-04-11          9                      8      16:01      埼玉        徳島
# 379 2021-04-11          9                      9      17:03    三協Ｆ柏       Ｇ大阪
#
#     home_goal away_goal away_team
# 0           0         2       川崎Ｆ
# 1           2         1        福岡
# 2           1         5        札幌
# 3           1         1        浦和
# 4           1         1        広島
# ..        ...       ...       ...
# 375         4         2      FC東京
# 376         0         3        鳥栖
# 377         3         0        大分
# 378         0         1        浦和
# 379         0         1         柏
#
# [380 rows x 9 columns]
